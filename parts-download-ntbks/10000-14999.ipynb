# %%
# imports
import os
import time
import numpy as np
import pandas as pd
import json
import spotipy
import yt_dlp

from spotipy.oauth2 import SpotifyClientCredentials

# %%
# data loading
data_json = pd.read_json('song-ids.json')
data_json = pd.DataFrame(data_json)
data_json = data_json.rename(columns={0: 'song_id'})
data_json
# Out:
#                       song_id
# 0      0pn7SynQPZBgNMlqPitrR6
# 1      1JsLA3JWc4XE2StbJcRYG6
# 2      23ssBTLuRpiE8hlCTEZCIk
# 3      6BPJCWBiFHF7ItUQlyyP6x
# 4      6GTVtjlDMEtnM2paZZ6VNe
# ...                       ...
# 24994  6Z1fY3aEN6dWMbLFSNCDYV
# 24995  2ljc7AncHJ7lZ7uTxALWLZ
# 24996  0B6g379TMw0nYGXA7y5xHz
# 24997  0VhkA3NAwIFfVW4NFCbAOD
# 24998  1HktSdwWZzAfxEHVSkBiB1
#
# [24999 rows x 1 columns]

# %%
# create a copy of the original dataframe (for appending song names)
data_json_copy = data_json
data_json_copy
# Out:
#                       song_id
# 0      0pn7SynQPZBgNMlqPitrR6
# 1      1JsLA3JWc4XE2StbJcRYG6
# 2      23ssBTLuRpiE8hlCTEZCIk
# 3      6BPJCWBiFHF7ItUQlyyP6x
# 4      6GTVtjlDMEtnM2paZZ6VNe
# ...                       ...
# 24994  6Z1fY3aEN6dWMbLFSNCDYV
# 24995  2ljc7AncHJ7lZ7uTxALWLZ
# 24996  0B6g379TMw0nYGXA7y5xHz
# 24997  0VhkA3NAwIFfVW4NFCbAOD
# 24998  1HktSdwWZzAfxEHVSkBiB1
#
# [24999 rows x 1 columns]

# %%
# api creds
client_id = ''
client_secret = ''

# %%
# initializing api client
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# song ids
song_ids = data_json['song_id'].tolist()
song_ids = song_ids[10000:15000]
print(song_ids)
# Out:
# ['11XLFFUNBk3vMKgblUAy1z', '7yip9pscRYhAwbZ4wfwQJx', '7556LMF1GR5QawF5PHLjI7', '68R32667rUVTo8ldDkOXyR', '4AxG1T6UJJ4xCX4Wz6JDLG', '5BKDqwrywwngFZyLpRdPhq', '0lZZ8pibk6Zu3M9hTthk1a', '6pdDXBRgRpcyGXcXJthNYC', '1PWVebG0tcyLyQYikv8JQS', '174gRALmmLbxeY4eUo2zCc', '0WJPw0kxOuBLjSAfXLLrSZ', '4GxdbaMtzN3jKJdjHpM3ET', '0i1RAruE7q6NJdoV3XKJk8', '6sT9MWlJManry3EQwf4V80', '4jkNGjbn7LZpgpRSOiJqCp', '42iXkSBfgzE7YyvKGZ7NzV', '2fSW54bA6x2iWePU7rpCiP', '2w1xQoej5TcciLKzx3DNzS', '7aCnhg8VU5XgUrgKCf9bET', '4DEY52zyUAQq4D5xeYUn4M', '3lCIV1noFOuHCtOCAeiBtN', '3S5AYyv0RYxNbUotueY32I', '4KjBDZps02XJYgQs9i6aUn', '73RbfOTJIjHzi2pcVHjeHM', '39BOpF8KvdMqUZlJyfnV34', '4OOLOIpYdw9oBSkdiHolgf', '0Pvrgc89C88HqJ8QRuukKh', '6mP31FqR4ZJzyrb4wVYuM5', '4LKfJMumpW7HyBT05uXYUx', '4LopAeo0EFicmQyh9lClkj', '6cstGFtvr32MNiv15foFlF', '1QQgmN383kUqjioRoTSfF3', '4J3MsRx4qGqmgtVCAA7f9R', '2YIDnkBfwbLMkt9rcugLdr', '0cwrUbIAPi1GNLrdIOT5Sd', '5hc71nKsUgtwQ3z52KEKQk', '0dTjGvzVRsvUjM9jJVWEDK', '2JKarN2L9zu2RaMx7gkkZ4', '3h1ipSBbufvYp6nDmkIJzQ', '41AYCzvMGOdYusD7tXriDI', '3LYACQmcsh5h1sy5jqnBtz', '5wKvJN1wpsr3sep9aafERM', '3zpgh23io9Y7RdFMf1wvcg', '1wFGZZgPRBDnyfeJPOxuES', '59OkS8s85lAvpVqCbJ1YPg', '4YPRYsbcOjoRWNRopyL34y', '3GNSai3WsE68E2p6MpKOct', '3jch551LjB77WRyhpdTMxm', '0XCuJNxpyNzJZdmE00hjEJ', '7j4TP90UjnBzQrEywzpnJj', '2e3OSiCXg1AcLFQ3HuiW42', '0W4G2TqiYXBvkyelLU90IK', '0Sg3UL7f40ulmTh0Xwr6qY', '17nLdkKJoPmuVARhIQEzWI', '3zmSVB4abatzdHsPXejp80', '1iQ8NkJgIYkUShqHy4WlTX', '0G5GZgjiV4kEo4KSqc7H3d', '6Sflud15ff1KqBzg6wj78S', '5ZY255MSISgMrvHmRZux1E', '41L3O37CECZt3N7ziG2z7l', '3UdSY1SgSF60lpYdMbmeXm', '5KXp9E22MHunsS4W4PNBUf', '6FZmo34ScBLpWYZxoOFnua', '0XkeIFTLS6XDdxYlJyeA2G', '2Fc10rM9quhIxQvXNb5gR8', '5gvrBqNFFEWcxYPt3mamvJ', '1EA40FX9aBaKIXwIp83WzL', '62ta8BEEecanvSxeS3FldL', '0QKfiqpEU4h9ycPSzIFwYe', '14341PCTnxSgULfXtPRCGu', '4h1VLpsN8tl5J1c8nsrUCa', '50pkO56KXHoH53sVPRSbZ3', '48NL8GMxz08wkiGmGK6Wie', '2ISfZ6F3gjHu3edhQke8N2', '2i958lqdtujEtWNkPZCzfo', '39tSGA5WvmdEmTnmuaU1vM', '5JxLTujYvge0kROrxHjUuf', '23qJaZCsjhJ5zBQ6C42a35', '7bu6mONyGzHfXmRvhJ1mki', '6s36KDFgCWW4lqDJ0njm7p', '6YAngZqMTJyorUHoeOpaqy', '2tx5JfgfigeVEUAiISw3qW', '1E8TaeHtclGpOsQSo97nsk', '1YcAHAuurahm6s1RVN8fzX', '0w3nrGKsQIU4HYRskCclDY', '77hy1Umsp0q0MSAwcj1RL4', '1nDgPqq5gsQince3gJJ6dQ', '51GDMymVXDYCac7xNFc29e', '1mppNVGh4ipsxIWUUA0QiH', '29wXmjhfMpDiGwTQVnLohf', '0Dc7J9VPV4eOInoxUiZrsL', '10waMsh44ojvTwXAIy213n', '4azbiOwp1xEKpVYegmrESJ', '0ugaTYXWzEyAf8yA3xwW3o', '4nccLEqWlU3IHoDbu1ChBa', '4ym9YuWm5ZsmLSlBDUy9xb', '2s2fORtcrwKwsmC4jNc8mJ', '2OZfJcpzSFApBxUA0gXuJz', '0jdFDf14KK7v2jr00kw7YH', '2LKOHdMsL0K9KwcPRlJK2v', '4ASiz8RUTRDVRyhnoneQeN', '29FNeqjOV2kPWGS55qhtGB', '7bmcIiFoBjWrNxMmAOLwGW', '4Mj3h4Q5MnzHwd3xHlxC05', '2OIK5BqmbOWPZCNQwt4gsN', '3a9qk3EgQhV9d3Qj8dp5wX', '4lr9J43vFZNhLULfXyheMR', '1oB7UDgAwpnsBBv03aOHEc', '5jhkdZWV0QDFzXdc1WAozs', '0GZfZOUpFBfArX6F50LXyf', '0ifSOpNqzeHNR6Z5UzLIUT', '6EXR6Z6YjOVHmKjH648H8Y', '4qwKWGKzuq8mgIunO6EaA1', '49vdEgZhz8Cd7c1pbPSl7B', '7c9OHViTralZa26DFOSTs2', '3cQX3RX0nRrxIbFTjDrC1a', '4WtWrOHAEAFL7aOWJKQnGN', '2bdLhiXfnLbr1KESzZwr18', '2sz3OHQWeOncPZc60uHQue', '2lS5DVXCyXHR2GSqyqKzES', '4lEVoOnIybtRqi4knZwdPZ', '7d87WUgIjJcEOYAYVbR86X', '0CmR4NDzyLtAFWs14bTp10', '7fxSLnklnayJNBIKntXedZ', '3XS4m5U98NBYUTvjN9FISB', '0aexPYQmV6pxL9QLLotPjH', '3JWSmiXZlAXRAtuza8FQgA', '1CwbCCoilQZCTvNETowFBi', '0CXVjQI9wsqaGeIARkkpYc', '6ICTnGsaokIDEYobnwuCjZ', '2q4rjDy9WhaN3o9MvDbO21', '5n2V631qeQri7jI6Kvbm4j', '63ZedTAVRCICh2CNLWnsPZ', '5VphpldmtVyZH6S8RpHWLT', '2l2yRJWgMiJkfPbRNiuC25', '3ua8wdqzl3SdgElppgcuf2', '1W4qc7UnAuRmT93W8Ad1t1', '5SdtsRnoG5T80AddV8OU3J', '2NSWi83peog6gHerzlMCqU', '3ilp9U50Ak4CKkS7jdCY4L', '6fvufkAyE5PIJsJiKdQ9yB', '0ZxhtATQ0a6EvQNZ0z6NKV', '58B7hILDpjNEdT8AWC6lGH', '2y0hUGvHaKm2p5xmJF4HBe', '01PCVuhAgFXmqr5YKNxNx0', '54X78diSLoUDI3joC2bjMz', '4rfppti0ptXnY8U7viMiHt', '7o67roCVsFiCt7Cf0ZLOJq', '0IlS5t1TOaRmMyScR6osc5', '5fHgBb5r91Jmdr8Q7dwmad', '4DhDNNhIDdduS6nZMbSMbs', '42zEjGGfKicxuzbXmEx4ck', '733RnlYLskyvWMhhzs70sy', '05fmEMCxNkpTbujVwRXZ ...

# %%
# create download directory
download_dir = f"song_ids_downloads"
os.makedirs(download_dir, exist_ok=True)

# %%
# yt track download options
ydl_opts = {
    'outtmpl': f"{download_dir}/%(title)s.%(ext)s",
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }],
}

# %%
# getting track details for entire list and downloading from youtube
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    for song_id in song_ids:
        track_info = sp.track(song_id)
        title = track_info['name']
        artist = track_info['artists'][0]['name']
        
        # start indexing from 1
        print(f"Downloading {song_ids.index(song_id)} of {len(song_ids)}")
        print(f"Downloading: {title} - {artist}")
        query = f"{title} {artist}"

        try:
            ydl.download([f"ytsearch:{query}"])
            info_query = ydl.extract_info(f"ytsearch:{query}", download=False)

            # get url of the first search result
            url = info_query['entries'][0]['webpage_url']

            # get title of the downloaded video and store in video_title variable
            info_url = ydl.extract_info(url, download=False)
            video_title = info_url.get('title')

            print(f"Downloaded: {title} - {artist}")

            # save title to a new column in the dataframe
            data_json_copy.at[song_ids.index(song_id)+10000, 'song_name'] = f"{video_title}.mp3"

        except yt_dlp.utils.DownloadError as e:
            print(f"Error downloading {title} - {artist}: {e}")
            data_json_copy.at[song_ids.index(song_id)+10000, 'song_name'] = f"NaN"

        # 10s timeout to avoid getting rate limited
        time.sleep(10)

# %%
# updated dataframe
data_json_copy

# %%
# save the new dataframe as a csv
data_json_copy.to_csv('data_json_copy3.csv', index=False)
