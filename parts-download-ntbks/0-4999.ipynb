# %%
# imports
import os
import time
import numpy as np
import pandas as pd
import json
import spotipy
import yt_dlp

from spotipy.oauth2 import SpotifyClientCredentials

# %%
# data loading
data_json = pd.read_json('song-ids.json')
data_json = pd.DataFrame(data_json)
data_json = data_json.rename(columns={0: 'song_id'})
data_json
# Out:
#                       song_id
# 0      0pn7SynQPZBgNMlqPitrR6
# 1      1JsLA3JWc4XE2StbJcRYG6
# 2      23ssBTLuRpiE8hlCTEZCIk
# 3      6BPJCWBiFHF7ItUQlyyP6x
# 4      6GTVtjlDMEtnM2paZZ6VNe
# ...                       ...
# 24994  6Z1fY3aEN6dWMbLFSNCDYV
# 24995  2ljc7AncHJ7lZ7uTxALWLZ
# 24996  0B6g379TMw0nYGXA7y5xHz
# 24997  0VhkA3NAwIFfVW4NFCbAOD
# 24998  1HktSdwWZzAfxEHVSkBiB1
#
# [24999 rows x 1 columns]

# %%
# create a copy of the original dataframe (for appending song names)
data_json_copy = data_json
data_json_copy
# Out:
#                       song_id
# 0      0pn7SynQPZBgNMlqPitrR6
# 1      1JsLA3JWc4XE2StbJcRYG6
# 2      23ssBTLuRpiE8hlCTEZCIk
# 3      6BPJCWBiFHF7ItUQlyyP6x
# 4      6GTVtjlDMEtnM2paZZ6VNe
# ...                       ...
# 24994  6Z1fY3aEN6dWMbLFSNCDYV
# 24995  2ljc7AncHJ7lZ7uTxALWLZ
# 24996  0B6g379TMw0nYGXA7y5xHz
# 24997  0VhkA3NAwIFfVW4NFCbAOD
# 24998  1HktSdwWZzAfxEHVSkBiB1
#
# [24999 rows x 1 columns]

# %%
# api creds
client_id = ''
client_secret = ''

# %%
# initializing api client
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# song ids
song_ids = data_json['song_id'].tolist()
song_ids = song_ids[:5000]
print(song_ids)
# Out:
# ['0pn7SynQPZBgNMlqPitrR6', '1JsLA3JWc4XE2StbJcRYG6', '23ssBTLuRpiE8hlCTEZCIk', '6BPJCWBiFHF7ItUQlyyP6x', '6GTVtjlDMEtnM2paZZ6VNe', '0qlCTm0U6Jcgx29HEYIXrg', '4a0sqvCBo7aRIS4GzBQpnp', '35QiTFf7gjbYmZ0Sj7dd3n', '2HEt32GOG4LhdkAcwkVDPD', '4kiwnJJ6ThoXzEean8UI1f', '4PCOSYkwl0aWdal9iZP1Oy', '1R7TwnwF1RuYNf5vXlpQUT', '2V65y3PX4DkRhy1djlxd9p', '6gTbAJOvivFXwkOEhSIOtS', '7gohMujUKNwS2ocu7I7yVW', '7n8lRa37iDNelsWw8JmoX4', '7vrJn5hDSXRmdXoR30KgF1', '3U70BInxXP4XBO7Bhyty7X', '6eCNz55YybdERmd840hKZa', '0IKc0xOUToF1PanrCgDUs1', '21hfiYaPDN8E14Trp4qTF3', '7jJ3EWr0umPsjC6CEupXRK', '4dHdqpGaO9km4TEw9nNQSR', '4DkjZPCTvs3W2VVyDi4MAt', '7pbg3ABlAZv2NiIdKbBBFm', '2wmrHfBFcCCYVdrlrUrJw3', '0OUQhRKgGSb0PPrLUuEQka', '49dFv4gH1SeY90FySDOwCE', '1vN8k0BhCIUrjsWCeAMpOW', '04aAxqtGp5pv12UXAg4pkq', '6Ec5LeRzkisa5KJtwLfOoW', '0FjBNvLsCCNu7vmCh8mZns', '7pG2i1QLokufVdQTbHsM0c', '0USw1cIvmZPOoU6pBGKWLR', '7A9EcBrwTG6bwswUy7beWW', '3CnK206lwL8j2ETlzBC9go', '2Tj9aHtf7g8ydYqsB6S9M5', '55Am8neGJkdj2ADaM3aw5H', '4aVQevcrgVDwqtRujqZrui', '5uPNU10StS3wF1jfewbomi', '5BOtcyDwMPNAU9O0RX2CbJ', '5N9wLoOxkCZcNhxRdMG70W', '1PWpeF2KQQzBjqkJPMqvpJ', '6UsDf89sHDBewBBw7hc0Qc', '6Rv8Ltr2MuAIM3LHF4L8qs', '3NSpAXJ6a3F0aVGd2VoAOW', '59BhNnVBBXKhUjONX7jlrk', '5cfIibuUGxlrdXcNaWmAnQ', '4w8niZpiMy6qz1mntFA5uM', '2biZJ6YK8Pz1bUby8VDV3Q', '0rCW64jnBDqjcdPClYFPyF', '3U8MbjNAP56IrzpbEFn1qN', '1hjRhYpWyqDpPahmSlUTlc', '2PLi7OmleXPNBrGLon3sUy', '7gDwRzJhLs0fFHaGtMDJVM', '4MctSXmoAjXq6z8pX85iBA', '763hp5LccmT6CrpsnA57zc', '3wiKJ8i3Ixdrc3qxBFFbPM', '4gsWvET11Mfb0ojrlgIfvu', '51bwChuoablcgmmSjvwe8Y', '3CeCwYWvdfXbZLXFhBrbnf', '4LO5DjN6Tp3UkUvgESuy2t', '0bmCrlc6LcIxhICRZ3CUbf', '0F7FA14euOIX8KcbEturGH', '1npqP0Epwvvc1jzudkkmVB', '3SKzTIl9mW0DadTys9SFo3', '3WHcJlIKMN6blaVjUiMI7v', '6uV6otgRs8LHuHDgllLwUo', '3stnrhzN0lzZFskbaZ5sEw', '5g8y52H5k4VuOuIS8eaaQ6', '60VXcWPc11I2sGjeNPRgbe', '6iX8XnMGHT9cNPPa7RQAjM', '6J56Td7qsOpP0YighOsWL6', '4vOoQh9MhS9pyrbvc8LyMz', '6tDxrq4FxEL2q15y37tXT9', '7uYbeh3ae4Hzne0SWacr3p', '5S4dSt2wKB4uFoIXI6W1VU', '3wdnX9UwfyXkNq0FJVhQQD', '52BJJwFAdeIGDbdAdtg896', '6mUNR2pJOxKRCVo97YVlHE', '5gH0dRKgk401aI5JGOuDu3', '1ivjor2exP7M405yRQ5SEC', '1uwQsyvo5QFD4zVb2PAqk5', '1SgENhaSaWJ9OWci6zRAvD', '1SKPmfSYaPsETbRHaiA18G', '0sYLS9g61uh9VoADfOpnpe', '0nudrF7WUr6R5OEVffxuky', '1LPgmcF3F2Hp8Rd69dREpW', '51CGbL9BAw1896waeHoR9w', '4yKN43pgKLGsoGZWpHpW5A', '6FAYpZ4jve8vpvTwUvjK6H', '3DQGpmTE2PxtFagccs6XDF', '3J9RgzjfVuVnGlPjenqVho', '3TysRQuZRfhXZ6P8T09YdO', '6IPlT00osBw6MgAhDvnPIy', '4G9m6QCYfnbALKjvCWZUN0', '61gGD55RS6Rje0t4GdaoAg', '3942GmjzxfLpo84f8iE1ah', '0Ph6L4l8dYUuXFmb71Ajnd', '2HbNk42mjGVPp0nWYrRLDS', '7gQlGAb4BDWWXahEONVjVn', '62A9O04etYcSU93mlbEgx7', '28cnXtME493VX9NOw9cIUh', '3YcPKmntW2DwQoRPYEkaO0', '52Zr0sinhWTCRrQhRRY4EP', '0EyxB6uQOUC4ex2tbJuu6m', '29U7stRjqHU6rMiS8BfaI9', '2aQpISWUBToaF84DDiTeRV', '1Ci4wASMY4xtKVMeHA6Sd5', '2hxIDFrGAADuMQ8H3KeyQY', '6V6Fma9lttQBnIaeHdZ4eC', '0miB2Y7zYt8DMx8biwooN2', '7aKWgpecgLEqisWcXPElDl', '24ylIO48nRsdaONlM8l2HF', '1fQaoh3imrMunWVZh5kf90', '4pV49P2v3sxI0XYjUTmOl1', '6QSJvH2m7QLAiFIywwzCVi', '7oT7E9mKx0u4P1CxXnvnSx', '1Hohk6AufHZOrrhMXZppax', '54n13PffD4WyldPwguU2Q6', '5jg3xtvH1ZkLO2XtaefaSF', '1wzqpoUSZ9vMKjvuHoqZFh', '3j84U36KvLeXNDPv4t5pI8', '44nBUw38dEsIl83lZIH3GJ', '3jqBLwtTiUYismDiZgAgPE', '6hbAVcAB0mQVXMPubZnwuL', '7rvgrmZdQeR1qDdzLLbo4Q', '3dKgDjL69KuoyMNeYfUbWJ', '7p8UZ2zaQzMn3uxLmFZf79', '4KM77RUl2IKdXGhtOBbKIS', '3EDSUk2mQbvQMTxP6XpF0K', '6nkxIA8MKHQT6R8nI63c9u', '6yZJigvD7SCYOp7tL8AtuB', '4rO5zu1AX5VILmhJ6kV1ia', '2ii4OMvYuKkRe7o4Xy68RH', '4iRRAvxPPWXQp3mV1rAbPF', '7mHpQooX9GfAAvszmMRZZu', '1Wcr8zrKqbUX0zwN8Dbr16', '0k2GOhqsrxDTAbFFSdNJjT', '4wlOGHCurUTa60NQGP2pXV', '5lnL6CCOxSx0KgPycBMFiz', '0GdWRgFmO6ETUiN5E4OZQq', '07FkzikE6FuHIa8Ma7zJGc', '5JkALM9RiMKLvQNWqUiMBP', '5lcueaBFTcHpQdiOdRIzgo', '4xlpJ99yL9xYQtzG6c3hwk', '6Um358vY92UBv5DloTRX9L', '3ozivYJGJGq6TSzdy8m64X', '1O8IG955aMrMS0ZkHyEg6i', '5rZlwNFl01HqLWBQGryKSm', '6hLkeOMrhZ2CMLBp2of576', '3fopcCEKZaG9Mg6ZhNQzqm', '0ExnxL921iSSl5kjOEJIbh', '42Nq9ljowxr7R7El55gQ ...

# %%
# create download directory
download_dir = f"song_ids_downloads"
os.makedirs(download_dir, exist_ok=True)

# %%
# yt track download options
ydl_opts = {
    'outtmpl': f"{download_dir}/%(title)s.%(ext)s",
    'format': 'bestaudio/best',
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192',
    }],
}

# %%
# getting track details for entire list and downloading from youtube
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    for song_id in song_ids:
        track_info = sp.track(song_id)
        title = track_info['name']
        artist = track_info['artists'][0]['name']
        
        # start indexing from 1
        print(f"Downloading {song_ids.index(song_id)} of {len(song_ids)}")
        print(f"Downloading: {title} - {artist}")
        query = f"{title} {artist}"

        try:
            ydl.download([f"ytsearch:{query}"])
            info_query = ydl.extract_info(f"ytsearch:{query}", download=False)

            # get url of the first search result
            url = info_query['entries'][0]['webpage_url']

            # get title of the downloaded video and store in video_title variable
            info_url = ydl.extract_info(url, download=False)
            video_title = info_url.get('title')

            print(f"Downloaded: {title} - {artist}")

            # save title to a new column in the dataframe
            data_json_copy.at[song_ids.index(song_id), 'song_name'] = f"{video_title}.mp3"

        except yt_dlp.utils.DownloadError as e:
            print(f"Error downloading {title} - {artist}: {e}")
            data_json_copy.at[song_ids.index(song_id), 'song_name'] = f"NaN"

        # 10s timeout to avoid getting rate limited
        time.sleep(10)

# %%
# updated dataframe
data_json_copy

# %%
# save the new dataframe as a csv
data_json_copy.to_csv('data_json_copy1.csv', index=False)
